# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hold = [0, 0, 0, 0, 0, 0] 

#load data

dataframes = ['15', '16', '17', '18', '19', '20']
names = hold.copy()
placehold = names.copy()

for x in range(6):
    placehold[x] = '20{}_CO_DATA.csv'.format(dataframes[x])
    names[x] = pd.read_csv('co_data\\' + placehold[x])
    names[x].dropna(inplace = True)
    
#unpack names

co15, co16, co17, co18, co19, co20 = names

# %%
co20
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour CO Concentration UNITS  \
# 0    1/1/2020    AQS  240053001    1                                0.4   ppm
# 1    1/2/2020    AQS  240053001    1                                1.3   ppm
# 2    1/3/2020    AQS  240053001    1                                0.6   ppm
# 3    1/4/2020    AQS  240053001    1                                0.5   ppm
# 4    1/5/2020    AQS  240053001    1                                0.4   ppm
# ..        ...    ...        ...  ...                                ...   ...
# 83  3/28/2020    AQS  240053001    1                                0.5   ppm
# 84  3/29/2020    AQS  240053001    1                                0.2   ppm
# 85  3/30/2020    AQS  240053001    1                                0.2   ppm
# 86  3/31/2020    AQS  240053001    1                                0.2   ppm
# 87   4/1/2020    AQS  240053001    1                                0.2   ppm
#
#     DAILY_AQI_VALUE Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                 5     Essex               19                79
# 1                15     Essex               24               100
# 2                 7     Essex               24               100
# 3                 6     Essex               24               100
# 4                 5     Essex               24               100
# ..              ...       ...              ...               ...
# 83                6     Essex               24               100
# 84                2     Essex               24               100
# 85                2     Essex               24               100
# 86                2     Essex               24               100
# 87                2     Essex                2                 8
#
#     AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# 0                42101    Carbon monoxide      12580
# 1                42101    Carbon monoxide      12580
# 2                42101    Carbon monoxide      12580
# 3                42101    Carbon monoxide      12580
# 4                42101    Carbon monoxide      12580
# ..                 ...                ...        ...
# 83               42101    Carbon monoxide      12580
# 84               42101    Carbon monoxide      12580
# 85               42101    Carbon monoxide      12580
# 86               42101    Carbon monoxide      12580
# 87               42101    Carbon monoxide      12580
#
#                         CBSA_NAME  STATE_CODE     STATE  COUNTY_CODE  \
# 0   Baltimore-Columbia-Towson, MD          24  Maryland            5
# 1   Baltimore-Columbia-Towson, MD          24  Maryland            5
# 2   Baltimore-Columbia-Towson, MD          24  Maryland            5
# 3   Baltimore-Columbia-Towson, MD          24  Maryland            5
# 4   Baltimore-Columbia-Towson, MD          24  Maryland            5
# ..                            ...         ...       ...          ...
# 83  Baltimore-Columbia-Towson, MD          24  Maryland            5
# 84  Baltimore-Columbia-Towson, MD          24  Maryland            5
# 85  Baltimore-Columbia-Towson, MD          24  Maryland            5
# 86  Baltimore-Columbia-Towson, MD          24  Maryland            5
# 87  Baltimore-Columbia-Towson, MD          24  Maryland            5
#
#        COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0   Baltimore      39.310833      -76.474444
# 1   Baltimore      39.310833      -76.474444
# 2   Baltimore      39.310833      -76.474444
# 3   Baltimore      39.310833      -76.474444
# 4   Baltimore      39.310833      -76.474444
# ..        ...            ...             ...
# 83  Baltimore      39.310833      -76.474444
# 84  Baltimore      39.310833      -76.474444
# 85  Baltimore      39.310833      -76.474444
# 86  Baltimore      39.310833      -76.474444
# 87  Baltimore      39.310833      -76.474444
#
# [88 rows x 20 columns]

# %%
co15
# Out:
#            Date Source      Site ID  POC  Daily Max 8-hour CO Concentration  \
# 0      1/1/2015    AQS  240053001.0  1.0                                0.4
# 1      1/2/2015    AQS  240053001.0  1.0                                1.0
# 2      1/3/2015    AQS  240053001.0  1.0                                1.3
# 3      1/4/2015    AQS  240053001.0  1.0                                0.4
# 4      1/5/2015    AQS  240053001.0  1.0                                0.1
# ..          ...    ...          ...  ...                                ...
# 352  12/27/2015    AQS  240053001.0  1.0                                0.2
# 353  12/28/2015    AQS  240053001.0  1.0                                0.2
# 354  12/29/2015    AQS  240053001.0  1.0                                0.6
# 355  12/30/2015    AQS  240053001.0  1.0                                0.5
# 356  12/31/2015    AQS  240053001.0  1.0                                0.3
#
#     UNITS  DAILY_AQI_VALUE Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0     ppm              5.0     Essex             19.0              79.0
# 1     ppm             11.0     Essex             24.0             100.0
# 2     ppm             15.0     Essex             24.0             100.0
# 3     ppm              5.0     Essex             24.0             100.0
# 4     ppm              1.0     Essex             24.0             100.0
# ..    ...              ...       ...              ...               ...
# 352   ppm              2.0     Essex             24.0             100.0
# 353   ppm              2.0     Essex             24.0             100.0
# 354   ppm              7.0     Essex             24.0             100.0
# 355   ppm              6.0     Essex             24.0             100.0
# 356   ppm              3.0     Essex             24.0             100.0
#
#      AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               42101.0    Carbon monoxide    12580.0
# 1               42101.0    Carbon monoxide    12580.0
# 2               42101.0    Carbon monoxide    12580.0
# 3               42101.0    Carbon monoxide    12580.0
# 4               42101.0    Carbon monoxide    12580.0
# ..                  ...                ...        ...
# 352             42101.0    Carbon monoxide    12580.0
# 353             42101.0    Carbon monoxide    12580.0
# 354             42101.0    Carbon monoxide    12580.0
# 355             42101.0    Carbon monoxide    12580.0
# 356             42101.0    Carbon monoxide    12580.0
#
#                          CBSA_NAME  STATE_CODE     STATE  COUNTY_CODE  \
# 0    Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 1    Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 2    Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 3    Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 4    Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# ..                             ...         ...       ...          ...
# 352  Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 353  Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 354  Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 355  Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
# 356  Baltimore-Columbia-Towson, MD        24.0  Maryland          5.0
#
#         COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0    Baltimore      39.310833      -76.474444
# 1    Baltimore      39.310833      -76.474444
# 2    Baltimore      39.310833      -76.474444
# 3    Baltimore      39.310833      -76.474444
# 4    Baltimore      39.310833      -76.474444
# ..         ...            ...             ...
# 352  Baltimore      39.310833      -76.474444
# 353  Baltimore      39.310833      -76.474444
# 354  Baltimore      39.310833      -76.474444
# 355  Baltimore      39.310833      -76.474444
# 356  Baltimore      39.310833      -76.474444
#
# [357 rows x 20 columns]

# %%
#extract aqi

aqiholder = names.copy()
for x in range(6):
    aqiholder[x] = names[x]['DAILY_AQI_VALUE']

#name aqi

aqi_15, aqi_16, aqi_17, aqi_18, aqi_19, aqi_20 = aqiholder

#extract date

dateholder = names.copy()
for x in range(6):
    dateholder[x] = names[x]['Date']
    
#name dates

date_15, date_16, date_17, date_18, date_19, date_20 = dateholder

# %%
#date reformat - find change in month and record the index where changes, use index to mark month

def month_index(x):
    monthHolder = []
    for i, j in enumerate(x):
        if i == 0:
            monthHolder.append(i)
        else:
            if j[0:2] != x[i-1][0:2]:
                monthHolder.append(i)
    return monthHolder
# Out:
# [0, 31, 59, 89, 119, 150, 177, 204, 235, 265, 296, 326]

# %%
plt.figure(figsize=(60,20))
plt.plot(date_15, aqi_15)
plt.title('2015 AQI Data', fontsize=70)

# x axis
plt.xlabel('Date', fontsize=60)
plt.xticks(month_index(date_15))
plt.xticks(fontsize=30)

# y axis
plt.ylabel('Air Quality Index', fontsize=60)
plt.yticks(fontsize = 30)


plt.grid()
plt.show()

# %%
plt.figure(figsize=(60,20))
plt.plot(date_20, aqi_20)
plt.title('2020 AQI Data vs 2015 AQI Data', fontsize=70)

# x axis
plt.xlabel('Date', fontsize=60)
plt.xticks(month_index(date_20))
plt.xticks(fontsize=30)

# y axis
plt.ylabel('Air Quality Index', fontsize=60)
plt.yticks(fontsize = 30)
plt.plot(aqi_15[0:88], 'r')


plt.grid(linewidth=3)
plt.show()
